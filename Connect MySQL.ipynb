# %%
import pymysql

# %%
conn=pymysql.connect(database='adventureworks',user='root',password='')

# %%
cursor=conn.cursor()

# %%
cursor.execute('select * from product;')
# Out:
# 504

# %%
rows = cursor.fetchall()
rows
# Out:
# ((1,
#   'Adjustable Race',
#   'AR-5381',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (2,
#   'Bearing Ball',
#   'BA-8327',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (3,
#   'BB Ball Bearing',
#   'BE-2349',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (4,
#   'Headset Ball Bearings',
#   'BE-2908',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (316, 'Blade', 'BL-2036', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (317,
#   'LL Crankarm',
#   'CA-5965',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (318,
#   'ML Crankarm',
#   'CA-6738',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (319,
#   'HL Crankarm',
#   'CA-7457',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (320,
#   'Chainring Bolts',
#   'CB-2903',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (321,
#   'Chainring Nut',
#   'CN-6137',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (322, 'Chainring', 'CR-7833', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (323,
#   'Crown Race',
#   'CR-9981',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (324,
#   'Chain Stays',
#   'CS-2812',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (325, 'Decal 1', 'DC-8732', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (326, 'Decal 2', 'DC-9824', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (327, 'Down Tube', 'DT-2377', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (328,
#   'Mountain End Caps',
#   'EC-M092',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (329,
#   'Road End Caps',
#   'EC-R098',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (330,
#   'Touring End Caps',
#   'EC-T209',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (331, 'Fork End', 'FE-3760', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (332, 'Freewheel', 'FH-2981', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (341,
#   'Flat Washer 1',
#   'FW-1000',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (342,
#   'Flat Washer 6',
#   'FW-1200',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (343,
#   'Flat Washer 2',
#   'FW-1400',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (344,
#   'Flat Washer 9',
#   'FW-3400',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (345,
#   'Flat Washer 4',
#   'FW-3800',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (346,
#   'Flat Washer 3',
#   'FW-5160',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (347,
#   'Flat Washer 8',
#   'FW-5800',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (348,
#   'Flat Washer 5',
#   'FW-7160',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (349,
#   'Flat Washer 7',
#   'FW-9160',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (350,
#   'Fork Crown',
#   'FC-3654',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (351,
#   'Front Derailleur Cage',
#   'FC-3982',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (352,
#   'Front Derailleur Linkage',
#   'FL-2301',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (355,
#   'Guide Pulley',
#   'GP-0982',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (356,
#   'LL Grip Tape',
#   'GT-0820',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (357,
#   'ML Grip Tape',
#   'GT-1209',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (358,
#   'HL Grip Tape',
#   'GT-2908',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (359,
#   'Thin-Jam Hex Nut 9',
#   'HJ-1213',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (360,
#   'Thin-Jam Hex Nut 10',
#   'HJ-1220',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (361,
#   'Thin-Jam Hex Nut 1',
#   'HJ-1420',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (362,
#   'Thin-Jam Hex Nut 2',
#   'HJ-1428',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (363,
#   'Thin-Jam Hex Nut 15',
#   'HJ-3410',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (364,
#   'Thin-Jam Hex Nut 16',
#   'HJ-3416',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (365,
#   'Thin-Jam Hex Nut 5',
#   'HJ-3816',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (366,
#   'Thin-Jam Hex Nut 6',
#   'HJ-3824',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (367,
#   'Thin-Jam Hex Nut 3',
#   'HJ-5161',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (368,
#   'Thin-Jam Hex Nut 4',
#   'HJ-5162',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (369,
#   'Thin-Jam Hex Nut 13',
#   'HJ-5811',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (370,
#   'Thin-Jam Hex Nut 14',
#   'HJ-5818',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (371,
#   'Thin-Jam Hex Nut 7',
#   'HJ-7161',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (372,
#   'Thin-Jam Hex Nut 8',
#   'HJ-7162',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (373,
#   'Thin-Jam Hex Nut 12',
#   'HJ-9080',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (374,
#   'Thin-Jam Hex Nut 11',
#   'HJ-9161',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (375, 'Hex Nut 5', 'HN-1024', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (376, 'Hex Nut 6', 'HN-1032', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (377,
#   'Hex Nut 16',
#   'HN-1213',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (378,
#   'Hex Nut 17',
#   'HN-1220',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (379, 'Hex Nut 7', 'HN-1224', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (380, 'Hex Nut 8', 'HN-1420', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (381, 'Hex Nut 9', 'HN-1428', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (382,
#   'Hex Nut 22',
#   'HN-3410',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (383,
#   'Hex Nut 23',
#   'HN-3416',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (384,
#   'Hex Nut 12',
#   'HN-3816',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (385,
#   'Hex Nut 13',
#   'HN-3824',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (386, 'Hex Nut 1', 'HN-4402', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (387,
#   'Hex Nut 10',
#   'HN-5161',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (388,
#   'Hex Nut 11',
#   'HN-5162',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (389, 'Hex Nut 2', 'HN-5400', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (390,
#   'Hex Nut 20',
#   'HN-5811',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (391,
#   'Hex Nut 21',
#   'HN-5818',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (392, 'Hex Nut 3', 'HN-6320', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (393,
#   'Hex Nut 14',
#   'HN-7161',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (394,
#   'Hex Nut 15',
#   'HN-7162',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (395, 'Hex Nut 4', 'HN-8320', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (396,
#   'Hex Nut 18',
#   'HN-9161',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (397,
#   'Hex Nut 19',
#   'HN-9168',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (398,
#   'Handlebar Tube',
#   'HT-2981',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (399, 'Head Tube', 'HT-8019', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (400, 'LL Hub', 'HU-6280', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (401, 'HL Hub', 'HU-8998', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (402,
#   'Keyed Washer',
#   'KW-4091',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (403,
#   'External Lock Washer 3',
#   'LE-1000',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (404,
#   'External Lock Washer 4',
#   'LE-1200',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (405,
#   'External Lock Washer 9',
#   'LE-1201',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (406,
#   'External Lock Washer 5',
#   'LE-1400',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (407,
#   'External Lock Washer 7',
#   'LE-3800',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (408,
#   'External Lock Washer 6',
#   'LE-5160',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (409,
#   'External Lock Washer 1',
#   'LE-6000',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (410,
#   'External Lock Washer 8',
#   'LE-7160',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (411,
#   'External Lock Washer 2',
#   'LE-8000',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (412,
#   'Internal Lock Washer 3',
#   'LI-1000',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (413,
#   'Internal Lock Washer 4',
#   'LI-1200',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (414,
#   'Internal Lock Washer 9',
#   'LI-1201',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (415,
#   'Internal Lock Washer 5',
#   'LI-1400',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (416,
#   'Internal Lock Washer 7',
#   'LI-3800',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (417,
#   'Internal Lock Washer 6',
#   'LI-5160',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (418,
#   'Internal Lock Washer 10',
#   'LI-5800',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (419,
#   'Internal Lock Washer 1',
#   'LI-6000',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (420,
#   'Internal Lock Washer 8',
#   'LI-7160',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (421,
#   'Internal Lock Washer 2',
#   'LI-8000',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (422,
#   'Thin-Jam Lock Nut 9',
#   'LJ-1213',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (423,
#   'Thin-Jam Lock Nut 10',
#   'LJ-1220',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (424,
#   'Thin-Jam Lock Nut 1',
#   'LJ-1420',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (425,
#   'Thin-Jam Lock Nut 2',
#   'LJ-1428',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (426,
#   'Thin-Jam Lock Nut 15',
#   'LJ-3410',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (427,
#   'Thin-Jam Lock Nut 16',
#   'LJ-3416',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (428,
#   'Thin-Jam Lock Nut 5',
#   'LJ-3816',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (429,
#   'Thin-Jam Lock Nut 6',
#   'LJ-3824',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (430,
#   'Thin-Jam Lock Nut 3',
#   'LJ-5161',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (431,
#   'Thin-Jam Lock Nut 4',
#   'LJ-5162',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (432,
#   'Thin-Jam Lock Nut 13',
#   'LJ-5811',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (433,
#   'Thin-Jam Lock Nut 14',
#   'LJ-5818',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (434,
#   'Thin-Jam Lock Nut 7',
#   'LJ-7161',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (435,
#   'Thin-Jam Lock Nut 8',
#   'LJ-7162',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (436,
#   'Thin-Jam Lock Nut 12',
#   'LJ-9080',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (437,
#   'Thin-Jam Lock Nut 11',
#   'LJ-9161',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (438,
#   'Lock Nut 5',
#   'LN-1024',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (439,
#   'Lock Nut 6',
#   'LN-1032',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (440,
#   'Lock Nut 16',
#   'LN-1213',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (441,
#   'Lock Nut 17',
#   'LN-1220',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (442,
#   'Lock Nut 7',
#   'LN-1224',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (443,
#   'Lock Nut 8',
#   'LN-1420',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (444,
#   'Lock Nut 9',
#   'LN-1428',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (445,
#   'Lock Nut 22',
#   'LN-3410',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (446,
#   'Lock Nut 23',
#   'LN-3416',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (447,
#   'Lock Nut 12',
#   'LN-3816',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (448,
#   'Lock Nut 13',
#   'LN-3824',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (449,
#   'Lock Nut 1',
#   'LN-4400',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (450,
#   'Lock Nut 10',
#   'LN-5161',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (451,
#   'Lock Nut 11',
#   'LN-5162',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (452,
#   'Lock Nut 2',
#   'LN-5400',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (453,
#   'Lock Nut 20',
#   'LN-5811',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (454,
#   'Lock Nut 21',
#   'LN-5818',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (455,
#   'Lock Nut 3',
#   'LN-6320',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (456,
#   'Lock Nut 14',
#   'LN-7161',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (457,
#   'Lock Nut 15',
#   'LN-7162',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (458,
#   'Lock Nut 4',
#   'LN-8320',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (459,
#   'Lock Nut 19',
#   'LN-9080',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (460,
#   'Lock Nut 18',
#   'LN-9161',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (461, 'Lock Ring', 'LR-2398', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (462,
#   'Lower Head Race',
#   'LR-8520',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (463,
#   'Lock Washer 4',
#   'LW-1000',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (464,
#   'Lock Washer 5',
#   'LW-1200',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (465,
#   'Lock Washer 10',
#   'LW-1201',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (466,
#   'Lock Washer 6',
#   'LW-1400',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (467,
#   'Lock Washer 13',
#   'LW-3400',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (468,
#   'Lock Washer 8',
#   'LW-3800',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (469,
#   'Lock Washer 1',
#   'LW-4000',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (470,
#   'Lock Washer 7',
#   'LW-5160',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (471,
#   'Lock Washer 12',
#   'LW-5800',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (472,
#   'Lock Washer 2',
#   'LW-6000',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (473,
#   'Lock Washer 9',
#   'LW-7160',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (474,
#   'Lock Washer 3',
#   'LW-8000',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (475,
#   'Lock Washer 11',
#   'LW-9160',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (476,
#   'Metal Angle',
#   'MA-7075',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (477,
#   'Metal Bar 1',
#   'MB-2024',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (478,
#   'Metal Bar 2',
#   'MB-6061',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (479,
#   'Metal Plate 2',
#   'MP-2066',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (480,
#   'Metal Plate 1',
#   'MP-2503',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (481,
#   'Metal Plate 3',
#   'MP-4960',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (482,
#   'Metal Sheet 2',
#   'MS-0253',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (483,
#   'Metal Sheet 3',
#   'MS-1256',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (484,
#   'Metal Sheet 7',
#   'MS-1981',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (485,
#   'Metal Sheet 4',
#   'MS-2259',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (486,
#   'Metal Sheet 5',
#   'MS-2341',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (487,
#   'Metal Sheet 6',
#   'MS-2348',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (488,
#   'Metal Sheet 1',
#   'MS-6061',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (489,
#   'Metal Tread Plate',
#   'MT-1000',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (490, 'LL Nipple', 'NI-4127', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (491, 'HL Nipple', 'NI-9522', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (492,
#   'Paint - Black',
#   'PA-187B',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (493,
#   'Paint - Red',
#   'PA-361R',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (494,
#   'Paint - Silver',
#   'PA-529S',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (495,
#   'Paint - Blue',
#   'PA-632U',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (496,
#   'Paint - Yellow',
#   'PA-823Y',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (497,
#   'Pinch Bolt',
#   'PB-6109',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (504,
#   'Cup-Shaped Race',
#   'RA-2345',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (505,
#   'Cone-Shaped Race',
#   'RA-7490',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (506, 'Reflector', 'RF-9198', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (507,
#   'LL Mountain Rim',
#   'RM-M464',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (508,
#   'ML Mountain Rim',
#   'RM-M692',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (509,
#   'HL Mountain Rim',
#   'RM-M823',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (510,
#   'LL Road Rim',
#   'RM-R436',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (511,
#   'ML Road Rim',
#   'RM-R600',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (512,
#   'HL Road Rim',
#   'RM-R800',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (513,
#   'Touring Rim',
#   'RM-T801',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (514,
#   'LL Mountain Seat Assembly',
#   'SA-M198',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (515,
#   'ML Mountain Seat Assembly',
#   'SA-M237',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (516,
#   'HL Mountain Seat Assembly',
#   'SA-M687',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (517,
#   'LL Road Seat Assembly',
#   'SA-R127',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (518,
#   'ML Road Seat Assembly',
#   'SA-R430',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (519,
#   'HL Road Seat Assembly',
#   'SA-R522',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (520,
#   'LL Touring Seat Assembly',
#   'SA-T467',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (521,
#   'ML Touring Seat Assembly',
#   'SA-T612',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (522,
#   'HL Touring Seat Assembly',
#   'SA-T872',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (523,
#   'LL Spindle/Axle',
#   'SD-2342',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (524,
#   'HL Spindle/Axle',
#   'SD-9872',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (525, 'LL Shell', 'SH-4562', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (526, 'HL Shell', 'SH-9312', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (527, 'Spokes', 'SK-9283', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (528, 'Seat Lug', 'SL-0931', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (529, 'Stem', 'SM-9087', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (530, 'Seat Post', 'SP-2981', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (531, 'Steerer', 'SR-2098', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (532,
#   'Seat Stays',
#   'SS-2985',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (533, 'Seat Tube', 'ST-9828', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (534, 'Top Tube', 'TO-2301', None, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (535,
#   'Tension Pulley',
#   'TP-0923',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (679,
#   'Rear Derailleur Cage',
#   'RC-0291',
#   None,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (680,
#   'HL Road Frame - Black, 58',
#   'FR-R92B-58',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (706,
#   'HL Road Frame - Red, 58',
#   'FR-R92R-58',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (707,
#   'Sport-100 Helmet, Red',
#   'HL-U509-R',
#   31,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (708,
#   'Sport-100 Helmet, Black',
#   'HL-U509',
#   31,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (709,
#   'Mountain Bike Socks, M',
#   'SO-B909-M',
#   23,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (710,
#   'Mountain Bike Socks, L',
#   'SO-B909-L',
#   23,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (711,
#   'Sport-100 Helmet, Blue',
#   'HL-U509-B',
#   31,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (712,
#   'AWC Logo Cap',
#   'CA-1098',
#   19,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (713,
#   'Long-Sleeve Logo Jersey, S',
#   'LJ-0192-S',
#   21,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (714,
#   'Long-Sleeve Logo Jersey, M',
#   'LJ-0192-M',
#   21,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (715,
#   'Long-Sleeve Logo Jersey, L',
#   'LJ-0192-L',
#   21,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (716,
#   'Long-Sleeve Logo Jersey, XL',
#   'LJ-0192-X',
#   21,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (717,
#   'HL Road Frame - Red, 62',
#   'FR-R92R-62',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (718,
#   'HL Road Frame - Red, 44',
#   'FR-R92R-44',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (719,
#   'HL Road Frame - Red, 48',
#   'FR-R92R-48',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (720,
#   'HL Road Frame - Red, 52',
#   'FR-R92R-52',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (721,
#   'HL Road Frame - Red, 56',
#   'FR-R92R-56',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (722,
#   'LL Road Frame - Black, 58',
#   'FR-R38B-58',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (723,
#   'LL Road Frame - Black, 60',
#   'FR-R38B-60',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (724,
#   'LL Road Frame - Black, 62',
#   'FR-R38B-62',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (725,
#   'LL Road Frame - Red, 44',
#   'FR-R38R-44',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (726,
#   'LL Road Frame - Red, 48',
#   'FR-R38R-48',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (727,
#   'LL Road Frame - Red, 52',
#   'FR-R38R-52',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (728,
#   'LL Road Frame - Red, 58',
#   'FR-R38R-58',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (729,
#   'LL Road Frame - Red, 60',
#   'FR-R38R-60',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (730,
#   'LL Road Frame - Red, 62',
#   'FR-R38R-62',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (731,
#   'ML Road Frame - Red, 44',
#   'FR-R72R-44',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (732,
#   'ML Road Frame - Red, 48',
#   'FR-R72R-48',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (733,
#   'ML Road Frame - Red, 52',
#   'FR-R72R-52',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (734,
#   'ML Road Frame - Red, 58',
#   'FR-R72R-58',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (735,
#   'ML Road Frame - Red, 60',
#   'FR-R72R-60',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (736,
#   'LL Road Frame - Black, 44',
#   'FR-R38B-44',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (737,
#   'LL Road Frame - Black, 48',
#   'FR-R38B-48',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (738,
#   'LL Road Frame - Black, 52',
#   'FR-R38B-52',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (739,
#   'HL Mountain Frame - Silver, 42',
#   'FR-M94S-42',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (740,
#   'HL Mountain Frame - Silver, 44',
#   'FR-M94S-44',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (741,
#   'HL Mountain Frame - Silver, 48',
#   'FR-M94S-52',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (742,
#   'HL Mountain Frame - Silver, 46',
#   'FR-M94S-46',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (743,
#   'HL Mountain Frame - Black, 42',
#   'FR-M94B-42',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (744,
#   'HL Mountain Frame - Black, 44',
#   'FR-M94B-44',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (745,
#   'HL Mountain Frame - Black, 48',
#   'FR-M94B-48',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (746,
#   'HL Mountain Frame - Black, 46',
#   'FR-M94B-46',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (747,
#   'HL Mountain Frame - Black, 38',
#   'FR-M94B-38',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (748,
#   'HL Mountain Frame - Silver, 38',
#   'FR-M94S-38',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (749,
#   'Road-150 Red, 62',
#   'BK-R93R-62',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (750,
#   'Road-150 Red, 44',
#   'BK-R93R-44',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (751,
#   'Road-150 Red, 48',
#   'BK-R93R-48',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (752,
#   'Road-150 Red, 52',
#   'BK-R93R-52',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (753,
#   'Road-150 Red, 56',
#   'BK-R93R-56',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (754,
#   'Road-450 Red, 58',
#   'BK-R68R-58',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (755,
#   'Road-450 Red, 60',
#   'BK-R68R-60',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (756,
#   'Road-450 Red, 44',
#   'BK-R68R-44',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (757,
#   'Road-450 Red, 48',
#   'BK-R68R-48',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (758,
#   'Road-450 Red, 52',
#   'BK-R68R-52',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (759,
#   'Road-650 Red, 58',
#   'BK-R50R-58',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (760,
#   'Road-650 Red, 60',
#   'BK-R50R-60',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (761,
#   'Road-650 Red, 62',
#   'BK-R50R-62',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (762,
#   'Road-650 Red, 44',
#   'BK-R50R-44',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (763,
#   'Road-650 Red, 48',
#   'BK-R50R-48',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (764,
#   'Road-650 Red, 52',
#   'BK-R50R-52',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (765,
#   'Road-650 Black, 58',
#   'BK-R50B-58',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (766,
#   'Road-650 Black, 60',
#   'BK-R50B-60',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (767,
#   'Road-650 Black, 62',
#   'BK-R50B-62',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (768,
#   'Road-650 Black, 44',
#   'BK-R50B-44',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (769,
#   'Road-650 Black, 48',
#   'BK-R50B-48',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (770,
#   'Road-650 Black, 52',
#   'BK-R50B-52',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (771,
#   'Mountain-100 Silver, 38',
#   'BK-M82S-38',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (772,
#   'Mountain-100 Silver, 42',
#   'BK-M82S-42',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (773,
#   'Mountain-100 Silver, 44',
#   'BK-M82S-44',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (774,
#   'Mountain-100 Silver, 48',
#   'BK-M82S-48',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (775,
#   'Mountain-100 Black, 38',
#   'BK-M82B-38',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (776,
#   'Mountain-100 Black, 42',
#   'BK-M82B-42',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (777,
#   'Mountain-100 Black, 44',
#   'BK-M82B-44',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (778,
#   'Mountain-100 Black, 48',
#   'BK-M82B-48',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (779,
#   'Mountain-200 Silver, 38',
#   'BK-M68S-38',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (780,
#   'Mountain-200 Silver, 42',
#   'BK-M68S-42',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (781,
#   'Mountain-200 Silver, 46',
#   'BK-M68S-46',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (782,
#   'Mountain-200 Black, 38',
#   'BK-M68B-38',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (783,
#   'Mountain-200 Black, 42',
#   'BK-M68B-42',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (784,
#   'Mountain-200 Black, 46',
#   'BK-M68B-46',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (785,
#   'Mountain-300 Black, 38',
#   'BK-M47B-38',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (786,
#   'Mountain-300 Black, 40',
#   'BK-M47B-40',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (787,
#   'Mountain-300 Black, 44',
#   'BK-M47B-44',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (788,
#   'Mountain-300 Black, 48',
#   'BK-M47B-48',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (789,
#   'Road-250 Red, 44',
#   'BK-R89R-44',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (790,
#   'Road-250 Red, 48',
#   'BK-R89R-48',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (791,
#   'Road-250 Red, 52',
#   'BK-R89R-52',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (792,
#   'Road-250 Red, 58',
#   'BK-R89R-58',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (793,
#   'Road-250 Black, 44',
#   'BK-R89B-44',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (794,
#   'Road-250 Black, 48',
#   'BK-R89B-48',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (795,
#   'Road-250 Black, 52',
#   'BK-R89B-52',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (796,
#   'Road-250 Black, 58',
#   'BK-R89B-58',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (797,
#   'Road-550-W Yellow, 38',
#   'BK-R64Y-38',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (798,
#   'Road-550-W Yellow, 40',
#   'BK-R64Y-40',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (799,
#   'Road-550-W Yellow, 42',
#   'BK-R64Y-42',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (800,
#   'Road-550-W Yellow, 44',
#   'BK-R64Y-44',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (801,
#   'Road-550-W Yellow, 48',
#   'BK-R64Y-48',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (802, 'LL Fork', 'FK-1639', 10, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (803, 'ML Fork', 'FK-5136', 10, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (804, 'HL Fork', 'FK-9939', 10, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (805, 'LL Headset', 'HS-0296', 11, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (806, 'ML Headset', 'HS-2451', 11, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (807, 'HL Headset', 'HS-3479', 11, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (808,
#   'LL Mountain Handlebars',
#   'HB-M243',
#   4,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (809,
#   'ML Mountain Handlebars',
#   'HB-M763',
#   4,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (810,
#   'HL Mountain Handlebars',
#   'HB-M918',
#   4,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (811,
#   'LL Road Handlebars',
#   'HB-R504',
#   4,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (812,
#   'ML Road Handlebars',
#   'HB-R720',
#   4,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (813,
#   'HL Road Handlebars',
#   'HB-R956',
#   4,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (814,
#   'ML Mountain Frame - Black, 38',
#   'FR-M63B-38',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (815,
#   'LL Mountain Front Wheel',
#   'FW-M423',
#   17,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (816,
#   'ML Mountain Front Wheel',
#   'FW-M762',
#   17,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (817,
#   'HL Mountain Front Wheel',
#   'FW-M928',
#   17,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (818,
#   'LL Road Front Wheel',
#   'FW-R623',
#   17,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (819,
#   'ML Road Front Wheel',
#   'FW-R762',
#   17,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (820,
#   'HL Road Front Wheel',
#   'FW-R820',
#   17,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (821,
#   'Touring Front Wheel',
#   'FW-T905',
#   17,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (822,
#   'ML Road Frame-W - Yellow, 38',
#   'FR-R72Y-38',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (823,
#   'LL Mountain Rear Wheel',
#   'RW-M423',
#   17,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (824,
#   'ML Mountain Rear Wheel',
#   'RW-M762',
#   17,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (825,
#   'HL Mountain Rear Wheel',
#   'RW-M928',
#   17,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (826,
#   'LL Road Rear Wheel',
#   'RW-R623',
#   17,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (827,
#   'ML Road Rear Wheel',
#   'RW-R762',
#   17,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (828,
#   'HL Road Rear Wheel',
#   'RW-R820',
#   17,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (829,
#   'Touring Rear Wheel',
#   'RW-T905',
#   17,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (830,
#   'ML Mountain Frame - Black, 40',
#   'FR-M63B-40',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (831,
#   'ML Mountain Frame - Black, 44',
#   'FR-M63B-44',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (832,
#   'ML Mountain Frame - Black, 48',
#   'FR-M63B-48',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (833,
#   'ML Road Frame-W - Yellow, 40',
#   'FR-R72Y-40',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (834,
#   'ML Road Frame-W - Yellow, 42',
#   'FR-R72Y-42',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (835,
#   'ML Road Frame-W - Yellow, 44',
#   'FR-R72Y-44',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (836,
#   'ML Road Frame-W - Yellow, 48',
#   'FR-R72Y-48',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (837,
#   'HL Road Frame - Black, 62',
#   'FR-R92B-62',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (838,
#   'HL Road Frame - Black, 44',
#   'FR-R92B-44',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (839,
#   'HL Road Frame - Black, 48',
#   'FR-R92B-48',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (840,
#   'HL Road Frame - Black, 52',
#   'FR-R92B-52',
#   14,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (841,
#   "Men's Sports Shorts, S",
#   'SH-M897-S',
#   22,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (842,
#   'Touring-Panniers, Large',
#   'PA-T100',
#   35,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (843, 'Cable Lock', 'LO-C100', 34, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (844, 'Minipump', 'PU-0452', 36, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (845,
#   'Mountain Pump',
#   'PU-M044',
#   36,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (846,
#   'Taillights - Battery-Powered',
#   'LT-T990',
#   33,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (847,
#   'Headlights - Dual-Beam',
#   'LT-H902',
#   33,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (848,
#   'Headlights - Weatherproof',
#   'LT-H903',
#   33,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (849,
#   "Men's Sports Shorts, M",
#   'SH-M897-M',
#   22,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (850,
#   "Men's Sports Shorts, L",
#   'SH-M897-L',
#   22,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (851,
#   "Men's Sports Shorts, XL",
#   'SH-M897-X',
#   22,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (852,
#   "Women's Tights, S",
#   'TG-W091-S',
#   24,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (853,
#   "Women's Tights, M",
#   'TG-W091-M',
#   24,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (854,
#   "Women's Tights, L",
#   'TG-W091-L',
#   24,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (855,
#   "Men's Bib-Shorts, S",
#   'SB-M891-S',
#   18,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (856,
#   "Men's Bib-Shorts, M",
#   'SB-M891-M',
#   18,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (857,
#   "Men's Bib-Shorts, L",
#   'SB-M891-L',
#   18,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (858,
#   'Half-Finger Gloves, S',
#   'GL-H102-S',
#   20,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (859,
#   'Half-Finger Gloves, M',
#   'GL-H102-M',
#   20,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (860,
#   'Half-Finger Gloves, L',
#   'GL-H102-L',
#   20,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (861,
#   'Full-Finger Gloves, S',
#   'GL-F110-S',
#   20,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (862,
#   'Full-Finger Gloves, M',
#   'GL-F110-M',
#   20,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (863,
#   'Full-Finger Gloves, L',
#   'GL-F110-L',
#   20,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (864,
#   'Classic Vest, S',
#   'VE-C304-S',
#   25,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (865,
#   'Classic Vest, M',
#   'VE-C304-M',
#   25,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (866,
#   'Classic Vest, L',
#   'VE-C304-L',
#   25,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (867,
#   "Women's Mountain Shorts, S",
#   'SH-W890-S',
#   22,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (868,
#   "Women's Mountain Shorts, M",
#   'SH-W890-M',
#   22,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (869,
#   "Women's Mountain Shorts, L",
#   'SH-W890-L',
#   22,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (870,
#   'Water Bottle - 30 oz.',
#   'WB-H098',
#   28,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (871,
#   'Mountain Bottle Cage',
#   'BC-M005',
#   28,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (872,
#   'Road Bottle Cage',
#   'BC-R205',
#   28,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (873,
#   'Patch Kit/8 Patches',
#   'PK-7098',
#   37,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (874,
#   'Racing Socks, M',
#   'SO-R809-M',
#   23,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (875,
#   'Racing Socks, L',
#   'SO-R809-L',
#   23,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (876,
#   'Hitch Rack - 4-Bike',
#   'RA-H123',
#   26,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (877,
#   'Bike Wash - Dissolver',
#   'CL-9009',
#   29,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (878,
#   'Fender Set - Mountain',
#   'FE-6654',
#   30,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (879,
#   'All-Purpose Bike Stand',
#   'ST-1401',
#   27,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (880,
#   'Hydration Pack - 70 oz.',
#   'HY-1023-70',
#   32,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (881,
#   'Short-Sleeve Classic Jersey, S',
#   'SJ-0194-S',
#   21,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (882,
#   'Short-Sleeve Classic Jersey, M',
#   'SJ-0194-M',
#   21,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (883,
#   'Short-Sleeve Classic Jersey, L',
#   'SJ-0194-L',
#   21,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (884,
#   'Short-Sleeve Classic Jersey, XL',
#   'SJ-0194-X',
#   21,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (885,
#   'HL Touring Frame - Yellow, 60',
#   'FR-T98Y-60',
#   16,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (886,
#   'LL Touring Frame - Yellow, 62',
#   'FR-T67Y-62',
#   16,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (887,
#   'HL Touring Frame - Yellow, 46',
#   'FR-T98Y-46',
#   16,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (888,
#   'HL Touring Frame - Yellow, 50',
#   'FR-T98Y-50',
#   16,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (889,
#   'HL Touring Frame - Yellow, 54',
#   'FR-T98Y-54',
#   16,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (890,
#   'HL Touring Frame - Blue, 46',
#   'FR-T98U-46',
#   16,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (891,
#   'HL Touring Frame - Blue, 50',
#   'FR-T98U-50',
#   16,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (892,
#   'HL Touring Frame - Blue, 54',
#   'FR-T98U-54',
#   16,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (893,
#   'HL Touring Frame - Blue, 60',
#   'FR-T98U-60',
#   16,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (894,
#   'Rear Derailleur',
#   'RD-2308',
#   9,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (895,
#   'LL Touring Frame - Blue, 50',
#   'FR-T67U-50',
#   16,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (896,
#   'LL Touring Frame - Blue, 54',
#   'FR-T67U-54',
#   16,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (897,
#   'LL Touring Frame - Blue, 58',
#   'FR-T67U-58',
#   16,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (898,
#   'LL Touring Frame - Blue, 62',
#   'FR-T67U-62',
#   16,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (899,
#   'LL Touring Frame - Yellow, 44',
#   'FR-T67Y-44',
#   16,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (900,
#   'LL Touring Frame - Yellow, 50',
#   'FR-T67Y-50',
#   16,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (901,
#   'LL Touring Frame - Yellow, 54',
#   'FR-T67Y-54',
#   16,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (902,
#   'LL Touring Frame - Yellow, 58',
#   'FR-T67Y-58',
#   16,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (903,
#   'LL Touring Frame - Blue, 44',
#   'FR-T67U-44',
#   16,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (904,
#   'ML Mountain Frame-W - Silver, 40',
#   'FR-M63S-40',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (905,
#   'ML Mountain Frame-W - Silver, 42',
#   'FR-M63S-42',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (906,
#   'ML Mountain Frame-W - Silver, 46',
#   'FR-M63S-46',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (907, 'Rear Brakes', 'RB-9231', 6, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (908,
#   'LL Mountain Seat/Saddle',
#   'SE-M236',
#   15,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (909,
#   'ML Mountain Seat/Saddle',
#   'SE-M798',
#   15,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (910,
#   'HL Mountain Seat/Saddle',
#   'SE-M940',
#   15,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (911,
#   'LL Road Seat/Saddle',
#   'SE-R581',
#   15,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (912,
#   'ML Road Seat/Saddle',
#   'SE-R908',
#   15,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (913,
#   'HL Road Seat/Saddle',
#   'SE-R995',
#   15,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (914,
#   'LL Touring Seat/Saddle',
#   'SE-T312',
#   15,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (915,
#   'ML Touring Seat/Saddle',
#   'SE-T762',
#   15,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (916,
#   'HL Touring Seat/Saddle',
#   'SE-T924',
#   15,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (917,
#   'LL Mountain Frame - Silver, 42',
#   'FR-M21S-42',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (918,
#   'LL Mountain Frame - Silver, 44',
#   'FR-M21S-44',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (919,
#   'LL Mountain Frame - Silver, 48',
#   'FR-M21S-48',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (920,
#   'LL Mountain Frame - Silver, 52',
#   'FR-M21S-52',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (921,
#   'Mountain Tire Tube',
#   'TT-M928',
#   37,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (922,
#   'Road Tire Tube',
#   'TT-R982',
#   37,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (923,
#   'Touring Tire Tube',
#   'TT-T092',
#   37,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (924,
#   'LL Mountain Frame - Black, 42',
#   'FR-M21B-42',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (925,
#   'LL Mountain Frame - Black, 44',
#   'FR-M21B-44',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (926,
#   'LL Mountain Frame - Black, 48',
#   'FR-M21B-48',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (927,
#   'LL Mountain Frame - Black, 52',
#   'FR-M21B-52',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (928,
#   'LL Mountain Tire',
#   'TI-M267',
#   37,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (929,
#   'ML Mountain Tire',
#   'TI-M602',
#   37,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (930,
#   'HL Mountain Tire',
#   'TI-M823',
#   37,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (931,
#   'LL Road Tire',
#   'TI-R092',
#   37,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (932,
#   'ML Road Tire',
#   'TI-R628',
#   37,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (933,
#   'HL Road Tire',
#   'TI-R982',
#   37,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (934,
#   'Touring Tire',
#   'TI-T723',
#   37,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (935,
#   'LL Mountain Pedal',
#   'PD-M282',
#   13,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (936,
#   'ML Mountain Pedal',
#   'PD-M340',
#   13,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (937,
#   'HL Mountain Pedal',
#   'PD-M562',
#   13,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (938,
#   'LL Road Pedal',
#   'PD-R347',
#   13,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (939,
#   'ML Road Pedal',
#   'PD-R563',
#   13,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (940,
#   'HL Road Pedal',
#   'PD-R853',
#   13,
#   datetime.datetime(2014, 2, 8, 10, 3, 56)),
#  (941,
#   'Touring Pedal',
#   'PD-T852',
#   13,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (942,
#   'ML Mountain Frame-W - Silver, 38',
#   'FR-M63S-38',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (943,
#   'LL Mountain Frame - Black, 40',
#   'FR-M21B-40',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (944,
#   'LL Mountain Frame - Silver, 40',
#   'FR-M21S-40',
#   12,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (945,
#   'Front Derailleur',
#   'FD-2342',
#   9,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (946,
#   'LL Touring Handlebars',
#   'HB-T721',
#   4,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (947,
#   'HL Touring Handlebars',
#   'HB-T928',
#   4,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (948, 'Front Brakes', 'FB-9873', 6, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (949, 'LL Crankset', 'CS-4759', 8, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (950, 'ML Crankset', 'CS-6583', 8, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (951, 'HL Crankset', 'CS-9183', 8, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (952, 'Chain', 'CH-0234', 7, datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (953,
#   'Touring-2000 Blue, 60',
#   'BK-T44U-60',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (954,
#   'Touring-1000 Yellow, 46',
#   'BK-T79Y-46',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (955,
#   'Touring-1000 Yellow, 50',
#   'BK-T79Y-50',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (956,
#   'Touring-1000 Yellow, 54',
#   'BK-T79Y-54',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (957,
#   'Touring-1000 Yellow, 60',
#   'BK-T79Y-60',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (958,
#   'Touring-3000 Blue, 54',
#   'BK-T18U-54',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (959,
#   'Touring-3000 Blue, 58',
#   'BK-T18U-58',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (960,
#   'Touring-3000 Blue, 62',
#   'BK-T18U-62',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (961,
#   'Touring-3000 Yellow, 44',
#   'BK-T18Y-44',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (962,
#   'Touring-3000 Yellow, 50',
#   'BK-T18Y-50',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (963,
#   'Touring-3000 Yellow, 54',
#   'BK-T18Y-54',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (964,
#   'Touring-3000 Yellow, 58',
#   'BK-T18Y-58',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (965,
#   'Touring-3000 Yellow, 62',
#   'BK-T18Y-62',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (966,
#   'Touring-1000 Blue, 46',
#   'BK-T79U-46',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (967,
#   'Touring-1000 Blue, 50',
#   'BK-T79U-50',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (968,
#   'Touring-1000 Blue, 54',
#   'BK-T79U-54',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (969,
#   'Touring-1000 Blue, 60',
#   'BK-T79U-60',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (970,
#   'Touring-2000 Blue, 46',
#   'BK-T44U-46',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (971,
#   'Touring-2000 Blue, 50',
#   'BK-T44U-50',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (972,
#   'Touring-2000 Blue, 54',
#   'BK-T44U-54',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (973,
#   'Road-350-W Yellow, 40',
#   'BK-R79Y-40',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (974,
#   'Road-350-W Yellow, 42',
#   'BK-R79Y-42',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (975,
#   'Road-350-W Yellow, 44',
#   'BK-R79Y-44',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (976,
#   'Road-350-W Yellow, 48',
#   'BK-R79Y-48',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (977,
#   'Road-750 Black, 58',
#   'BK-R19B-58',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (978,
#   'Touring-3000 Blue, 44',
#   'BK-T18U-44',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (979,
#   'Touring-3000 Blue, 50',
#   'BK-T18U-50',
#   3,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (980,
#   'Mountain-400-W Silver, 38',
#   'BK-M38S-38',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (981,
#   'Mountain-400-W Silver, 40',
#   'BK-M38S-40',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (982,
#   'Mountain-400-W Silver, 42',
#   'BK-M38S-42',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (983,
#   'Mountain-400-W Silver, 46',
#   'BK-M38S-46',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (984,
#   'Mountain-500 Silver, 40',
#   'BK-M18S-40',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (985,
#   'Mountain-500 Silver, 42',
#   'BK-M18S-42',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (986,
#   'Mountain-500 Silver, 44',
#   'BK-M18S-44',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (987,
#   'Mountain-500 Silver, 48',
#   'BK-M18S-48',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (988,
#   'Mountain-500 Silver, 52',
#   'BK-M18S-52',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (989,
#   'Mountain-500 Black, 40',
#   'BK-M18B-40',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (990,
#   'Mountain-500 Black, 42',
#   'BK-M18B-42',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (991,
#   'Mountain-500 Black, 44',
#   'BK-M18B-44',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (992,
#   'Mountain-500 Black, 48',
#   'BK-M18B-48',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (993,
#   'Mountain-500 Black, 52',
#   'BK-M18B-52',
#   1,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (994,
#   'LL Bottom Bracket',
#   'BB-7421',
#   5,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (995,
#   'ML Bottom Bracket',
#   'BB-8107',
#   5,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (996,
#   'HL Bottom Bracket',
#   'BB-9108',
#   5,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (997,
#   'Road-750 Black, 44',
#   'BK-R19B-44',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (998,
#   'Road-750 Black, 48',
#   'BK-R19B-48',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)),
#  (999,
#   'Road-750 Black, 52',
#   'BK-R19B-52',
#   2,
#   datetime.datetime(2014, 2, 8, 10, 1, 37)))

# %%
import data_slice

# %%
data_slice(rows,[],1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-492a6ce60bae> in <module>
# ----> 1 data_slice(rows,[],1)
#
# TypeError: 'module' object is not callable

# %%
def data_slice(rows,x):
    data=[]
    for i in range(len(rows)):
        data.append(rows[i][x])
    print (data)

# %%
data_slice(rows,1)
# Out:
# ['Adjustable Race', 'Bearing Ball', 'BB Ball Bearing', 'Headset Ball Bearings', 'Blade', 'LL Crankarm', 'ML Crankarm', 'HL Crankarm', 'Chainring Bolts', 'Chainring Nut', 'Chainring', 'Crown Race', 'Chain Stays', 'Decal 1', 'Decal 2', 'Down Tube', 'Mountain End Caps', 'Road End Caps', 'Touring End Caps', 'Fork End', 'Freewheel', 'Flat Washer 1', 'Flat Washer 6', 'Flat Washer 2', 'Flat Washer 9', 'Flat Washer 4', 'Flat Washer 3', 'Flat Washer 8', 'Flat Washer 5', 'Flat Washer 7', 'Fork Crown', 'Front Derailleur Cage', 'Front Derailleur Linkage', 'Guide Pulley', 'LL Grip Tape', 'ML Grip Tape', 'HL Grip Tape', 'Thin-Jam Hex Nut 9', 'Thin-Jam Hex Nut 10', 'Thin-Jam Hex Nut 1', 'Thin-Jam Hex Nut 2', 'Thin-Jam Hex Nut 15', 'Thin-Jam Hex Nut 16', 'Thin-Jam Hex Nut 5', 'Thin-Jam Hex Nut 6', 'Thin-Jam Hex Nut 3', 'Thin-Jam Hex Nut 4', 'Thin-Jam Hex Nut 13', 'Thin-Jam Hex Nut 14', 'Thin-Jam Hex Nut 7', 'Thin-Jam Hex Nut 8', 'Thin-Jam Hex Nut 12', 'Thin-Jam Hex Nut 11', 'Hex Nut 5', 'Hex Nut 6', 'Hex Nut 16', 'Hex Nut 17', 'Hex Nut 7', 'Hex Nut 8', 'Hex Nut 9', 'Hex Nut 22', 'Hex Nut 23', 'Hex Nut 12', 'Hex Nut 13', 'Hex Nut 1', 'Hex Nut 10', 'Hex Nut 11', 'Hex Nut 2', 'Hex Nut 20', 'Hex Nut 21', 'Hex Nut 3', 'Hex Nut 14', 'Hex Nut 15', 'Hex Nut 4', 'Hex Nut 18', 'Hex Nut 19', 'Handlebar Tube', 'Head Tube', 'LL Hub', 'HL Hub', 'Keyed Washer', 'External Lock Washer 3', 'External Lock Washer 4', 'External Lock Washer 9', 'External Lock Washer 5', 'External Lock Washer 7', 'External Lock Washer 6', 'External Lock Washer 1', 'External Lock Washer 8', 'External Lock Washer 2', 'Internal Lock Washer 3', 'Internal Lock Washer 4', 'Internal Lock Washer 9', 'Internal Lock Washer 5', 'Internal Lock Washer 7', 'Internal Lock Washer 6', 'Internal Lock Washer 10', 'Internal Lock Washer 1', 'Internal Lock Washer 8', 'Internal Lock Washer 2', 'Thin-Jam Lock Nut 9', 'Thin-Jam Lock Nut 10', 'Thin-Jam Lock Nut 1', 'Thin-Jam Lock Nut 2', 'Thin-Jam Lock Nut 15', 'Thin-Jam Lock Nut 16', 'Thin-Jam Lock Nut 5', 'Thin-Jam Lock Nut 6', 'Thin-Jam Lock Nut 3', 'Thin-Jam Lock Nut 4', 'Thin-Jam Lock Nut 13', 'Thin-Jam Lock Nut 14', 'Thin-Jam Lock Nut 7', 'Thin-Jam Lock Nut 8', 'Thin-Jam Lock Nut 12', 'Thin-Jam Lock Nut 11', 'Lock Nut 5', 'Lock Nut 6', 'Lock Nut 16', 'Lock Nut 17', 'Lock Nut 7', 'Lock Nut 8', 'Lock Nut 9', 'Lock Nut 22', 'Lock Nut 23', 'Lock Nut 12', 'Lock Nut 13', 'Lock Nut 1', 'Lock Nut 10', 'Lock Nut 11', 'Lock Nut 2', 'Lock Nut 20', 'Lock Nut 21', 'Lock Nut 3', 'Lock Nut 14', 'Lock Nut 15', 'Lock Nut 4', 'Lock Nut 19', 'Lock Nut 18', 'Lock Ring', 'Lower Head Race', 'Lock Washer 4', 'Lock Washer 5', 'Lock Washer 10', 'Lock Washer 6', 'Lock Washer 13', 'Lock Washer 8', 'Lock Washer 1', 'Lock Washer 7', 'Lock Washer 12', 'Lock Washer 2', 'Lock Washer 9', 'Lock Washer 3', 'Lock Washer 11', 'Metal Angle', 'Metal Bar 1', 'Metal Bar 2', 'Metal Plate 2', 'Metal Plate 1', 'Metal Plate 3', 'Metal Sheet 2', 'Metal Sheet 3', 'Metal Sheet 7', 'Metal Sheet 4', 'Metal Sheet 5', 'Metal Sheet 6', 'Metal Sheet 1', 'Metal Tread Plate', 'LL Nipple', 'HL Nipple', 'Paint - Black', 'Paint - Red', 'Paint - Silver', 'Paint - Blue', 'Paint - Yellow', 'Pinch Bolt', 'Cup-Shaped Race', 'Cone-Shaped Race', 'Reflector', 'LL Mountain Rim', 'ML Mountain Rim', 'HL Mountain Rim', 'LL Road Rim', 'ML Road Rim', 'HL Road Rim', 'Touring Rim', 'LL Mountain Seat Assembly', 'ML Mountain Seat Assembly', 'HL Mountain Seat Assembly', 'LL Road Seat Assembly', 'ML Road Seat Assembly', 'HL Road Seat Assembly', 'LL Touring Seat Assembly', 'ML Touring Seat Assembly', 'HL Touring Seat Assembly', 'LL Spindle/Axle', 'HL Spindle/Axle', 'LL Shell', 'HL Shell', 'Spokes', 'Seat Lug', 'Stem', 'Seat Post', 'Steerer', 'Seat Stays', 'Seat Tube', 'Top Tube', 'Tension Pulley', 'Rear Derailleur Cage', 'HL Road Frame - Black, 58', 'HL Road Frame - Red, 58', 'Sport-100 Helmet, Red', 'Sport-100 Helmet, Black', 'Mountain Bike Socks, M', 'Mountain Bike Socks, L', 'Sport-100 Helmet, Blue', 'AWC Logo Cap', 'Long-Slee ...
