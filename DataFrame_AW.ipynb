# %%
import pandas as pd
import pyodbc
import matplotlib.pyplot as plt

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DESKTOP-JT7GQBL\SQLEXPRESS;'
                      'Database=AdventureWorks;'
                      'Trusted_Connection=yes;')

# %%
cursor = conn.cursor()

# %%
cursor.execute('SELECT COLUMN_NAME, * FROM INFORMATION_SCHEMA.COLUMNS')
rows = cursor.fetchall()
rows
# Out:
# [('BusinessEntityID', 'AdventureWorks', 'Person', 'vAdditionalContactInfo', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('FirstName', 'AdventureWorks', 'Person', 'vAdditionalContactInfo', 'FirstName', 2, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('MiddleName', 'AdventureWorks', 'Person', 'vAdditionalContactInfo', 'MiddleName', 3, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('LastName', 'AdventureWorks', 'Person', 'vAdditionalContactInfo', 'LastName', 4, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('TelephoneNumber', 'AdventureWorks', 'Person', 'vAdditionalContactInfo', 'TelephoneNumber', 5, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('TelephoneSpecialInstructions', 'AdventureWorks', 'Person', 'vAdditionalContactInfo', 'TelephoneSpecialInstructions', 6, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Street', 'AdventureWorks', 'Person', 'vAdditionalContactInfo', 'Street', 7, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('City', 'AdventureWorks', 'Person', 'vAdditionalContactInfo', 'City', 8, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('StateProvince', 'AdventureWorks', 'Person', 'vAdditionalContactInfo', 'StateProvince', 9, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('PostalCode', 'AdventureWorks', 'Person', 'vAdditionalContactInfo', 'PostalCode', 10, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('CountryRegion', 'AdventureWorks', 'Person', 'vAdditionalContactInfo', 'CountryRegion', 11, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('HomeAddressSpecialInstructions', 'AdventureWorks', 'Person', 'vAdditionalContactInfo', 'HomeAddressSpecialInstructions', 12, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('EMailAddress', 'AdventureWorks', 'Person', 'vAdditionalContactInfo', 'EMailAddress', 13, None, 'YES', 'nvarchar', 128, 256, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('EMailSpecialInstructions', 'AdventureWorks', 'Person', 'vAdditionalContactInfo', 'EMailSpecialInstructions', 14, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('EMailTelephoneNumber', 'AdventureWorks', 'Person', 'vAdditionalContactInfo', 'EMailTelephoneNumber', 15, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('rowguid', 'AdventureWorks', 'Person', 'vAdditionalContactInfo', 'rowguid', 16, None, 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('ModifiedDate', 'AdventureWorks', 'Person', 'vAdditionalContactInfo', 'ModifiedDate', 17, None, 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('BusinessEntityID', 'AdventureWorks', 'Person', 'PersonPhone', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('PhoneNumber', 'AdventureWorks', 'Person', 'PersonPhone', 'PhoneNumber', 2, None, 'NO', 'nvarchar', 25, 50, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Phone'),
#  ('PhoneNumberTypeID', 'AdventureWorks', 'Person', 'PersonPhone', 'PhoneNumberTypeID', 3, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('ModifiedDate', 'AdventureWorks', 'Person', 'PersonPhone', 'ModifiedDate', 4, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('BusinessEntityID', 'AdventureWorks', 'HumanResources', 'vEmployee', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Title', 'AdventureWorks', 'HumanResources', 'vEmployee', 'Title', 2, None, 'YES', 'nvarchar', 8, 16, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('FirstName', 'AdventureWorks', 'HumanResources', 'vEmployee', 'FirstName', 3, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('MiddleName', 'AdventureWorks', 'HumanResources', 'vEmployee', 'MiddleName', 4, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('LastName', 'AdventureWorks', 'HumanResources', 'vEmployee', 'LastName', 5, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('Suffix', 'AdventureWorks', 'HumanResources', 'vEmployee', 'Suffix', 6, None, 'YES', 'nvarchar', 10, 20, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('JobTitle', 'AdventureWorks', 'HumanResources', 'vEmployee', 'JobTitle', 7, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('PhoneNumber', 'AdventureWorks', 'HumanResources', 'vEmployee', 'PhoneNumber', 8, None, 'YES', 'nvarchar', 25, 50, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Phone'),
#  ('PhoneNumberType', 'AdventureWorks', 'HumanResources', 'vEmployee', 'PhoneNumberType', 9, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('EmailAddress', 'AdventureWorks', 'HumanResources', 'vEmployee', 'EmailAddress', 10, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('EmailPromotion', 'AdventureWorks', 'HumanResources', 'vEmployee', 'EmailPromotion', 11, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AddressLine1', 'AdventureWorks', 'HumanResources', 'vEmployee', 'AddressLine1', 12, None, 'NO', 'nvarchar', 60, 120, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('AddressLine2', 'AdventureWorks', 'HumanResources', 'vEmployee', 'AddressLine2', 13, None, 'YES', 'nvarchar', 60, 120, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('City', 'AdventureWorks', 'HumanResources', 'vEmployee', 'City', 14, None, 'NO', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('StateProvinceName', 'AdventureWorks', 'HumanResources', 'vEmployee', 'StateProvinceName', 15, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('PostalCode', 'AdventureWorks', 'HumanResources', 'vEmployee', 'PostalCode', 16, None, 'NO', 'nvarchar', 15, 30, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('CountryRegionName', 'AdventureWorks', 'HumanResources', 'vEmployee', 'CountryRegionName', 17, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('AdditionalContactInfo', 'AdventureWorks', 'HumanResources', 'vEmployee', 'AdditionalContactInfo', 18, None, 'YES', 'xml', -1, -1, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('TerritoryID', 'AdventureWorks', 'Sales', 'SalesTerritory', 'TerritoryID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Name', 'AdventureWorks', 'Sales', 'SalesTerritory', 'Name', 2, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('CountryRegionCode', 'AdventureWorks', 'Sales', 'SalesTerritory', 'CountryRegionCode', 3, None, 'NO', 'nvarchar', 3, 6, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Group', 'AdventureWorks', 'Sales', 'SalesTerritory', 'Group', 4, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('SalesYTD', 'AdventureWorks', 'Sales', 'SalesTerritory', 'SalesYTD', 5, '((0.00))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('SalesLastYear', 'AdventureWorks', 'Sales', 'SalesTerritory', 'SalesLastYear', 6, '((0.00))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('CostYTD', 'AdventureWorks', 'Sales', 'SalesTerritory', 'CostYTD', 7, '((0.00))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('CostLastYear', 'AdventureWorks', 'Sales', 'SalesTerritory', 'CostLastYear', 8, '((0.00))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('rowguid', 'AdventureWorks', 'Sales', 'SalesTerritory', 'rowguid', 9, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('ModifiedDate', 'AdventureWorks', 'Sales', 'SalesTerritory', 'ModifiedDate', 10, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('BusinessEntityID', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartment', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Title', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartment', 'Title', 2, None, 'YES', 'nvarchar', 8, 16, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('FirstName', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartment', 'FirstName', 3, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('MiddleName', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartment', 'MiddleName', 4, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('LastName', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartment', 'LastName', 5, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('Suffix', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartment', 'Suffix', 6, None, 'YES', 'nvarchar', 10, 20, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('JobTitle', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartment', 'JobTitle', 7, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Department', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartment', 'Department', 8, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('GroupName', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartment', 'GroupName', 9, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('StartDate', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartment', 'StartDate', 10, None, 'NO', 'date', None, None, None, None, None, 0, None, None, None, None, None, None, None, None, None),
#  ('PhoneNumberTypeID', 'AdventureWorks', 'Person', 'PhoneNumberType', 'PhoneNumberTypeID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Name', 'AdventureWorks', 'Person', 'PhoneNumberType', 'Name', 2, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('ModifiedDate', 'AdventureWorks', 'Person', 'PhoneNumberType', 'ModifiedDate', 3, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('BusinessEntityID', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartmentHistory', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Title', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartmentHistory', 'Title', 2, None, 'YES', 'nvarchar', 8, 16, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('FirstName', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartmentHistory', 'FirstName', 3, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('MiddleName', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartmentHistory', 'MiddleName', 4, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('LastName', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartmentHistory', 'LastName', 5, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('Suffix', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartmentHistory', 'Suffix', 6, None, 'YES', 'nvarchar', 10, 20, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Shift', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartmentHistory', 'Shift', 7, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('Department', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartmentHistory', 'Department', 8, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('GroupName', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartmentHistory', 'GroupName', 9, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('StartDate', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartmentHistory', 'StartDate', 10, None, 'NO', 'date', None, None, None, None, None, 0, None, None, None, None, None, None, None, None, None),
#  ('EndDate', 'AdventureWorks', 'HumanResources', 'vEmployeeDepartmentHistory', 'EndDate', 11, None, 'YES', 'date', None, None, None, None, None, 0, None, None, None, None, None, None, None, None, None),
#  ('BusinessEntityID', 'AdventureWorks', 'Sales', 'vIndividualCustomer', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Title', 'AdventureWorks', 'Sales', 'vIndividualCustomer', 'Title', 2, None, 'YES', 'nvarchar', 8, 16, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('FirstName', 'AdventureWorks', 'Sales', 'vIndividualCustomer', 'FirstName', 3, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('MiddleName', 'AdventureWorks', 'Sales', 'vIndividualCustomer', 'MiddleName', 4, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('LastName', 'AdventureWorks', 'Sales', 'vIndividualCustomer', 'LastName', 5, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('Suffix', 'AdventureWorks', 'Sales', 'vIndividualCustomer', 'Suffix', 6, None, 'YES', 'nvarchar', 10, 20, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('PhoneNumber', 'AdventureWorks', 'Sales', 'vIndividualCustomer', 'PhoneNumber', 7, None, 'YES', 'nvarchar', 25, 50, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Phone'),
#  ('PhoneNumberType', 'AdventureWorks', 'Sales', 'vIndividualCustomer', 'PhoneNumberType', 8, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('EmailAddress', 'AdventureWorks', 'Sales', 'vIndividualCustomer', 'EmailAddress', 9, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('EmailPromotion', 'AdventureWorks', 'Sales', 'vIndividualCustomer', 'EmailPromotion', 10, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('AddressType', 'AdventureWorks', 'Sales', 'vIndividualCustomer', 'AddressType', 11, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('AddressLine1', 'AdventureWorks', 'Sales', 'vIndividualCustomer', 'AddressLine1', 12, None, 'NO', 'nvarchar', 60, 120, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('AddressLine2', 'AdventureWorks', 'Sales', 'vIndividualCustomer', 'AddressLine2', 13, None, 'YES', 'nvarchar', 60, 120, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('City', 'AdventureWorks', 'Sales', 'vIndividualCustomer', 'City', 14, None, 'NO', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('StateProvinceName', 'AdventureWorks', 'Sales', 'vIndividualCustomer', 'StateProvinceName', 15, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('PostalCode', 'AdventureWorks', 'Sales', 'vIndividualCustomer', 'PostalCode', 16, None, 'NO', 'nvarchar', 15, 30, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('CountryRegionName', 'AdventureWorks', 'Sales', 'vIndividualCustomer', 'CountryRegionName', 17, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('Demographics', 'AdventureWorks', 'Sales', 'vIndividualCustomer', 'Demographics', 18, None, 'YES', 'xml', -1, -1, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('ProductID', 'AdventureWorks', 'Production', 'Product', 'ProductID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Name', 'AdventureWorks', 'Production', 'Product', 'Name', 2, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('ProductNumber', 'AdventureWorks', 'Production', 'Product', 'ProductNumber', 3, None, 'NO', 'nvarchar', 25, 50, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('MakeFlag', 'AdventureWorks', 'Production', 'Product', 'MakeFlag', 4, '((1))', 'NO', 'bit', None, None, None, None, None, None, None, None, None, None, None, None, 'AdventureWorks', 'dbo', 'Flag'),
#  ('FinishedGoodsFlag', 'AdventureWorks', 'Production', 'Product', 'FinishedGoodsFlag', 5, '((1))', 'NO', 'bit', None, None, None, None, None, None, None, None, None, None, None, None, 'AdventureWorks', 'dbo', 'Flag'),
#  ('Color', 'AdventureWorks', 'Production', 'Product', 'Color', 6, None, 'YES', 'nvarchar', 15, 30, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('SafetyStockLevel', 'AdventureWorks', 'Production', 'Product', 'SafetyStockLevel', 7, None, 'NO', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('ReorderPoint', 'AdventureWorks', 'Production', 'Product', 'ReorderPoint', 8, None, 'NO', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('StandardCost', 'AdventureWorks', 'Production', 'Product', 'StandardCost', 9, None, 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('ListPrice', 'AdventureWorks', 'Production', 'Product', 'ListPrice', 10, None, 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('Size', 'AdventureWorks', 'Production', 'Product', 'Size', 11, None, 'YES', 'nvarchar', 5, 10, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('SizeUnitMeasureCode', 'AdventureWorks', 'Production', 'Product', 'SizeUnitMeasureCode', 12, None, 'YES', 'nchar', 3, 6, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('WeightUnitMeasureCode', 'AdventureWorks', 'Production', 'Product', 'WeightUnitMeasureCode', 13, None, 'YES', 'nchar', 3, 6, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Weight', 'AdventureWorks', 'Production', 'Product', 'Weight', 14, None, 'YES', 'decimal', None, None, 8, 10, 2, None, None, None, None, None, None, None, None, None, None),
#  ('DaysToManufacture', 'AdventureWorks', 'Production', 'Product', 'DaysToManufacture', 15, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('ProductLine', 'AdventureWorks', 'Production', 'Product', 'ProductLine', 16, None, 'YES', 'nchar', 2, 4, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Class', 'AdventureWorks', 'Production', 'Product', 'Class', 17, None, 'YES', 'nchar', 2, 4, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Style', 'AdventureWorks', 'Production', 'Product', 'Style', 18, None, 'YES', 'nchar', 2, 4, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('ProductSubcategoryID', 'AdventureWorks', 'Production', 'Product', 'ProductSubcategoryID', 19, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('ProductModelID', 'AdventureWorks', 'Production', 'Product', 'ProductModelID', 20, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('SellStartDate', 'AdventureWorks', 'Production', 'Product', 'SellStartDate', 21, None, 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('SellEndDate', 'AdventureWorks', 'Production', 'Product', 'SellEndDate', 22, None, 'YES', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('DiscontinuedDate', 'AdventureWorks', 'Production', 'Product', 'DiscontinuedDate', 23, None, 'YES', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('rowguid', 'AdventureWorks', 'Production', 'Product', 'rowguid', 24, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('ModifiedDate', 'AdventureWorks', 'Production', 'Product', 'ModifiedDate', 25, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('BusinessEntityID', 'AdventureWorks', 'Sales', 'vPersonDemographics', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('TotalPurchaseYTD', 'AdventureWorks', 'Sales', 'vPersonDemographics', 'TotalPurchaseYTD', 2, None, 'YES', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('DateFirstPurchase', 'AdventureWorks', 'Sales', 'vPersonDemographics', 'DateFirstPurchase', 3, None, 'YES', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('BirthDate', 'AdventureWorks', 'Sales', 'vPersonDemographics', 'BirthDate', 4, None, 'YES', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('MaritalStatus', 'AdventureWorks', 'Sales', 'vPersonDemographics', 'MaritalStatus', 5, None, 'YES', 'nvarchar', 1, 2, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('YearlyIncome', 'AdventureWorks', 'Sales', 'vPersonDemographics', 'YearlyIncome', 6, None, 'YES', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Gender', 'AdventureWorks', 'Sales', 'vPersonDemographics', 'Gender', 7, None, 'YES', 'nvarchar', 1, 2, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('TotalChildren', 'AdventureWorks', 'Sales', 'vPersonDemographics', 'TotalChildren', 8, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('NumberChildrenAtHome', 'AdventureWorks', 'Sales', 'vPersonDemographics', 'NumberChildrenAtHome', 9, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Education', 'AdventureWorks', 'Sales', 'vPersonDemographics', 'Education', 10, None, 'YES', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Occupation', 'AdventureWorks', 'Sales', 'vPersonDemographics', 'Occupation', 11, None, 'YES', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('HomeOwnerFlag', 'AdventureWorks', 'Sales', 'vPersonDemographics', 'HomeOwnerFlag', 12, None, 'YES', 'bit', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('NumberCarsOwned', 'AdventureWorks', 'Sales', 'vPersonDemographics', 'NumberCarsOwned', 13, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('JobCandidateID', 'AdventureWorks', 'HumanResources', 'vJobCandidate', 'JobCandidateID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('BusinessEntityID', 'AdventureWorks', 'HumanResources', 'vJobCandidate', 'BusinessEntityID', 2, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Name.Prefix', 'AdventureWorks', 'HumanResources', 'vJobCandidate', 'Name.Prefix', 3, None, 'YES', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Name.First', 'AdventureWorks', 'HumanResources', 'vJobCandidate', 'Name.First', 4, None, 'YES', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Name.Middle', 'AdventureWorks', 'HumanResources', 'vJobCandidate', 'Name.Middle', 5, None, 'YES', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Name.Last', 'AdventureWorks', 'HumanResources', 'vJobCandidate', 'Name.Last', 6, None, 'YES', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Name.Suffix', 'AdventureWorks', 'HumanResources', 'vJobCandidate', 'Name.Suffix', 7, None, 'YES', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Skills', 'AdventureWorks', 'HumanResources', 'vJobCandidate', 'Skills', 8, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Addr.Type', 'AdventureWorks', 'HumanResources', 'vJobCandidate', 'Addr.Type', 9, None, 'YES', 'nvarchar', 30, 60, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Addr.Loc.CountryRegion', 'AdventureWorks', 'HumanResources', 'vJobCandidate', 'Addr.Loc.CountryRegion', 10, None, 'YES', 'nvarchar', 100, 200, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Addr.Loc.State', 'AdventureWorks', 'HumanResources', 'vJobCandidate', 'Addr.Loc.State', 11, None, 'YES', 'nvarchar', 100, 200, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Addr.Loc.City', 'AdventureWorks', 'HumanResources', 'vJobCandidate', 'Addr.Loc.City', 12, None, 'YES', 'nvarchar', 100, 200, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Addr.PostalCode', 'AdventureWorks', 'HumanResources', 'vJobCandidate', 'Addr.PostalCode', 13, None, 'YES', 'nvarchar', 20, 40, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('EMail', 'AdventureWorks', 'HumanResources', 'vJobCandidate', 'EMail', 14, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('WebSite', 'AdventureWorks', 'HumanResources', 'vJobCandidate', 'WebSite', 15, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('ModifiedDate', 'AdventureWorks', 'HumanResources', 'vJobCandidate', 'ModifiedDate', 16, None, 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('JobCandidateID', 'AdventureWorks', 'HumanResources', 'vJobCandidateEmployment', 'JobCandidateID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Emp.StartDate', 'AdventureWorks', 'HumanResources', 'vJobCandidateEmployment', 'Emp.StartDate', 2, None, 'YES', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('Emp.EndDate', 'AdventureWorks', 'HumanResources', 'vJobCandidateEmployment', 'Emp.EndDate', 3, None, 'YES', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('Emp.OrgName', 'AdventureWorks', 'HumanResources', 'vJobCandidateEmployment', 'Emp.OrgName', 4, None, 'YES', 'nvarchar', 100, 200, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Emp.JobTitle', 'AdventureWorks', 'HumanResources', 'vJobCandidateEmployment', 'Emp.JobTitle', 5, None, 'YES', 'nvarchar', 100, 200, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Emp.Responsibility', 'AdventureWorks', 'HumanResources', 'vJobCandidateEmployment', 'Emp.Responsibility', 6, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Emp.FunctionCategory', 'AdventureWorks', 'HumanResources', 'vJobCandidateEmployment', 'Emp.FunctionCategory', 7, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Emp.IndustryCategory', 'AdventureWorks', 'HumanResources', 'vJobCandidateEmployment', 'Emp.IndustryCategory', 8, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Emp.Loc.CountryRegion', 'AdventureWorks', 'HumanResources', 'vJobCandidateEmployment', 'Emp.Loc.CountryRegion', 9, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Emp.Loc.State', 'AdventureWorks', 'HumanResources', 'vJobCandidateEmployment', 'Emp.Loc.State', 10, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Emp.Loc.City', 'AdventureWorks', 'HumanResources', 'vJobCandidateEmployment', 'Emp.Loc.City', 11, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('JobCandidateID', 'AdventureWorks', 'HumanResources', 'vJobCandidateEducation', 'JobCandidateID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Edu.Level', 'AdventureWorks', 'HumanResources', 'vJobCandidateEducation', 'Edu.Level', 2, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Edu.StartDate', 'AdventureWorks', 'HumanResources', 'vJobCandidateEducation', 'Edu.StartDate', 3, None, 'YES', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('Edu.EndDate', 'AdventureWorks', 'HumanResources', 'vJobCandidateEducation', 'Edu.EndDate', 4, None, 'YES', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('Edu.Degree', 'AdventureWorks', 'HumanResources', 'vJobCandidateEducation', 'Edu.Degree', 5, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Edu.Major', 'AdventureWorks', 'HumanResources', 'vJobCandidateEducation', 'Edu.Major', 6, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Edu.Minor', 'AdventureWorks', 'HumanResources', 'vJobCandidateEducation', 'Edu.Minor', 7, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Edu.GPA', 'AdventureWorks', 'HumanResources', 'vJobCandidateEducation', 'Edu.GPA', 8, None, 'YES', 'nvarchar', 5, 10, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Edu.GPAScale', 'AdventureWorks', 'HumanResources', 'vJobCandidateEducation', 'Edu.GPAScale', 9, None, 'YES', 'nvarchar', 5, 10, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Edu.School', 'AdventureWorks', 'HumanResources', 'vJobCandidateEducation', 'Edu.School', 10, None, 'YES', 'nvarchar', 100, 200, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Edu.Loc.CountryRegion', 'AdventureWorks', 'HumanResources', 'vJobCandidateEducation', 'Edu.Loc.CountryRegion', 11, None, 'YES', 'nvarchar', 100, 200, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Edu.Loc.State', 'AdventureWorks', 'HumanResources', 'vJobCandidateEducation', 'Edu.Loc.State', 12, None, 'YES', 'nvarchar', 100, 200, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Edu.Loc.City', 'AdventureWorks', 'HumanResources', 'vJobCandidateEducation', 'Edu.Loc.City', 13, None, 'YES', 'nvarchar', 100, 200, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('ProductID', 'AdventureWorks', 'Production', 'vProductAndDescription', 'ProductID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Name', 'AdventureWorks', 'Production', 'vProductAndDescription', 'Name', 2, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('ProductModel', 'AdventureWorks', 'Production', 'vProductAndDescription', 'ProductModel', 3, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('CultureID', 'AdventureWorks', 'Production', 'vProductAndDescription', 'CultureID', 4, None, 'NO', 'nchar', 6, 12, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Description', 'AdventureWorks', 'Production', 'vProductAndDescription', 'Description', 5, None, 'NO', 'nvarchar', 400, 800, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('BusinessEntityID', 'AdventureWorks', 'Sales', 'vStoreWithContacts', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Name', 'AdventureWorks', 'Sales', 'vStoreWithContacts', 'Name', 2, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('ContactType', 'AdventureWorks', 'Sales', 'vStoreWithContacts', 'ContactType', 3, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('Title', 'AdventureWorks', 'Sales', 'vStoreWithContacts', 'Title', 4, None, 'YES', 'nvarchar', 8, 16, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('FirstName', 'AdventureWorks', 'Sales', 'vStoreWithContacts', 'FirstName', 5, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('MiddleName', 'AdventureWorks', 'Sales', 'vStoreWithContacts', 'MiddleName', 6, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('LastName', 'AdventureWorks', 'Sales', 'vStoreWithContacts', 'LastName', 7, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('Suffix', 'AdventureWorks', 'Sales', 'vStoreWithContacts', 'Suffix', 8, None, 'YES', 'nvarchar', 10, 20, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('PhoneNumber', 'AdventureWorks', 'Sales', 'vStoreWithContacts', 'PhoneNumber', 9, None, 'YES', 'nvarchar', 25, 50, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Phone'),
#  ('PhoneNumberType', 'AdventureWorks', 'Sales', 'vStoreWithContacts', 'PhoneNumberType', 10, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('EmailAddress', 'AdventureWorks', 'Sales', 'vStoreWithContacts', 'EmailAddress', 11, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('EmailPromotion', 'AdventureWorks', 'Sales', 'vStoreWithContacts', 'EmailPromotion', 12, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('ProductCategoryID', 'AdventureWorks', 'Production', 'ProductCategory', 'ProductCategoryID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Name', 'AdventureWorks', 'Production', 'ProductCategory', 'Name', 2, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('rowguid', 'AdventureWorks', 'Production', 'ProductCategory', 'rowguid', 3, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('ModifiedDate', 'AdventureWorks', 'Production', 'ProductCategory', 'ModifiedDate', 4, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('ShipMethodID', 'AdventureWorks', 'Purchasing', 'ShipMethod', 'ShipMethodID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Name', 'AdventureWorks', 'Purchasing', 'ShipMethod', 'Name', 2, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('ShipBase', 'AdventureWorks', 'Purchasing', 'ShipMethod', 'ShipBase', 3, '((0.00))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('ShipRate', 'AdventureWorks', 'Purchasing', 'ShipMethod', 'ShipRate', 4, '((0.00))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('rowguid', 'AdventureWorks', 'Purchasing', 'ShipMethod', 'rowguid', 5, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('ModifiedDate', 'AdventureWorks', 'Purchasing', 'ShipMethod', 'ModifiedDate', 6, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('ProductID', 'AdventureWorks', 'Production', 'ProductCostHistory', 'ProductID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('StartDate', 'AdventureWorks', 'Production', 'ProductCostHistory', 'StartDate', 2, None, 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('EndDate', 'AdventureWorks', 'Production', 'ProductCostHistory', 'EndDate', 3, None, 'YES', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('StandardCost', 'AdventureWorks', 'Production', 'ProductCostHistory', 'StandardCost', 4, None, 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('ModifiedDate', 'AdventureWorks', 'Production', 'ProductCostHistory', 'ModifiedDate', 5, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('ProductDescriptionID', 'AdventureWorks', 'Production', 'ProductDescription', 'ProductDescriptionID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Description', 'AdventureWorks', 'Production', 'ProductDescription', 'Description', 2, None, 'NO', 'nvarchar', 400, 800, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('rowguid', 'AdventureWorks', 'Production', 'ProductDescription', 'rowguid', 3, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('ModifiedDate', 'AdventureWorks', 'Production', 'ProductDescription', 'ModifiedDate', 4, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('ShoppingCartItemID', 'AdventureWorks', 'Sales', 'ShoppingCartItem', 'ShoppingCartItemID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('ShoppingCartID', 'AdventureWorks', 'Sales', 'ShoppingCartItem', 'ShoppingCartID', 2, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Quantity', 'AdventureWorks', 'Sales', 'ShoppingCartItem', 'Quantity', 3, '((1))', 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('ProductID', 'AdventureWorks', 'Sales', 'ShoppingCartItem', 'ProductID', 4, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('DateCreated', 'AdventureWorks', 'Sales', 'ShoppingCartItem', 'DateCreated', 5, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('ModifiedDate', 'AdventureWorks', 'Sales', 'ShoppingCartItem', 'ModifiedDate', 6, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('ProductID', 'AdventureWorks', 'Production', 'ProductDocument', 'ProductID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('DocumentNode', 'AdventureWorks', 'Production', 'ProductDocument', 'DocumentNode', 2, None, 'NO', 'hierarchyid', 892, 892, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('ModifiedDate', 'AdventureWorks', 'Production', 'ProductDocument', 'ModifiedDate', 3, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('DatabaseLogID', 'AdventureWorks', 'dbo', 'DatabaseLog', 'DatabaseLogID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('PostTime', 'AdventureWorks', 'dbo', 'DatabaseLog', 'PostTime', 2, None, 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('DatabaseUser', 'AdventureWorks', 'dbo', 'DatabaseLog', 'DatabaseUser', 3, None, 'NO', 'nvarchar', 128, 256, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Event', 'AdventureWorks', 'dbo', 'DatabaseLog', 'Event', 4, None, 'NO', 'nvarchar', 128, 256, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Schema', 'AdventureWorks', 'dbo', 'DatabaseLog', 'Schema', 5, None, 'YES', 'nvarchar', 128, 256, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Object', 'AdventureWorks', 'dbo', 'DatabaseLog', 'Object', 6, None, 'YES', 'nvarchar', 128, 256, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('TSQL', 'AdventureWorks', 'dbo', 'DatabaseLog', 'TSQL', 7, None, 'NO', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('XmlEvent', 'AdventureWorks', 'dbo', 'DatabaseLog', 'XmlEvent', 8, None, 'NO', 'xml', -1, -1, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('ProductID', 'AdventureWorks', 'Production', 'ProductInventory', 'ProductID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('LocationID', 'AdventureWorks', 'Production', 'ProductInventory', 'LocationID', 2, None, 'NO', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Shelf', 'AdventureWorks', 'Production', 'ProductInventory', 'Shelf', 3, None, 'NO', 'nvarchar', 10, 20, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Bin', 'AdventureWorks', 'Production', 'ProductInventory', 'Bin', 4, None, 'NO', 'tinyint', None, None, 3, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Quantity', 'AdventureWorks', 'Production', 'ProductInventory', 'Quantity', 5, '((0))', 'NO', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('rowguid', 'AdventureWorks', 'Production', 'ProductInventory', 'rowguid', 6, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
# ...
#  ('GroupName', 'AdventureWorks', 'HumanResources', 'Department', 'GroupName', 3, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'Name'),
#  ('ModifiedDate', 'AdventureWorks', 'HumanResources', 'Department', 'ModifiedDate', 4, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('DocumentNode', 'AdventureWorks', 'Production', 'Document', 'DocumentNode', 1, None, 'NO', 'hierarchyid', 892, 892, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('DocumentLevel', 'AdventureWorks', 'Production', 'Document', 'DocumentLevel', 2, None, 'YES', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Title', 'AdventureWorks', 'Production', 'Document', 'Title', 3, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Owner', 'AdventureWorks', 'Production', 'Document', 'Owner', 4, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('FolderFlag', 'AdventureWorks', 'Production', 'Document', 'FolderFlag', 5, '((0))', 'NO', 'bit', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('FileName', 'AdventureWorks', 'Production', 'Document', 'FileName', 6, None, 'NO', 'nvarchar', 400, 800, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('FileExtension', 'AdventureWorks', 'Production', 'Document', 'FileExtension', 7, None, 'NO', 'nvarchar', 8, 16, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Revision', 'AdventureWorks', 'Production', 'Document', 'Revision', 8, None, 'NO', 'nchar', 5, 10, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('ChangeNumber', 'AdventureWorks', 'Production', 'Document', 'ChangeNumber', 9, '((0))', 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('Status', 'AdventureWorks', 'Production', 'Document', 'Status', 10, None, 'NO', 'tinyint', None, None, 3, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('DocumentSummary', 'AdventureWorks', 'Production', 'Document', 'DocumentSummary', 11, None, 'YES', 'nvarchar', -1, -1, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Document', 'AdventureWorks', 'Production', 'Document', 'Document', 12, None, 'YES', 'varbinary', -1, -1, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('rowguid', 'AdventureWorks', 'Production', 'Document', 'rowguid', 13, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('ModifiedDate', 'AdventureWorks', 'Production', 'Document', 'ModifiedDate', 14, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('SalesOrderID', 'AdventureWorks', 'Sales', 'SalesOrderDetail', 'SalesOrderID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('SalesOrderDetailID', 'AdventureWorks', 'Sales', 'SalesOrderDetail', 'SalesOrderDetailID', 2, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('CarrierTrackingNumber', 'AdventureWorks', 'Sales', 'SalesOrderDetail', 'CarrierTrackingNumber', 3, None, 'YES', 'nvarchar', 25, 50, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('OrderQty', 'AdventureWorks', 'Sales', 'SalesOrderDetail', 'OrderQty', 4, None, 'NO', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('ProductID', 'AdventureWorks', 'Sales', 'SalesOrderDetail', 'ProductID', 5, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('SpecialOfferID', 'AdventureWorks', 'Sales', 'SalesOrderDetail', 'SpecialOfferID', 6, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('UnitPrice', 'AdventureWorks', 'Sales', 'SalesOrderDetail', 'UnitPrice', 7, None, 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('UnitPriceDiscount', 'AdventureWorks', 'Sales', 'SalesOrderDetail', 'UnitPriceDiscount', 8, '((0.0))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('LineTotal', 'AdventureWorks', 'Sales', 'SalesOrderDetail', 'LineTotal', 9, None, 'NO', 'numeric', None, None, 38, 10, 6, None, None, None, None, None, None, None, None, None, None),
#  ('rowguid', 'AdventureWorks', 'Sales', 'SalesOrderDetail', 'rowguid', 10, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('ModifiedDate', 'AdventureWorks', 'Sales', 'SalesOrderDetail', 'ModifiedDate', 11, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('BusinessEntityID', 'AdventureWorks', 'Person', 'EmailAddress', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('EmailAddressID', 'AdventureWorks', 'Person', 'EmailAddress', 'EmailAddressID', 2, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('EmailAddress', 'AdventureWorks', 'Person', 'EmailAddress', 'EmailAddress', 3, None, 'YES', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('rowguid', 'AdventureWorks', 'Person', 'EmailAddress', 'rowguid', 4, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('ModifiedDate', 'AdventureWorks', 'Person', 'EmailAddress', 'ModifiedDate', 5, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('BusinessEntityID', 'AdventureWorks', 'HumanResources', 'Employee', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('NationalIDNumber', 'AdventureWorks', 'HumanResources', 'Employee', 'NationalIDNumber', 2, None, 'NO', 'nvarchar', 15, 30, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('LoginID', 'AdventureWorks', 'HumanResources', 'Employee', 'LoginID', 3, None, 'NO', 'nvarchar', 256, 512, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('OrganizationNode', 'AdventureWorks', 'HumanResources', 'Employee', 'OrganizationNode', 4, None, 'YES', 'hierarchyid', 892, 892, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('OrganizationLevel', 'AdventureWorks', 'HumanResources', 'Employee', 'OrganizationLevel', 5, None, 'YES', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('JobTitle', 'AdventureWorks', 'HumanResources', 'Employee', 'JobTitle', 6, None, 'NO', 'nvarchar', 50, 100, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('BirthDate', 'AdventureWorks', 'HumanResources', 'Employee', 'BirthDate', 7, None, 'NO', 'date', None, None, None, None, None, 0, None, None, None, None, None, None, None, None, None),
#  ('MaritalStatus', 'AdventureWorks', 'HumanResources', 'Employee', 'MaritalStatus', 8, None, 'NO', 'nchar', 1, 2, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('Gender', 'AdventureWorks', 'HumanResources', 'Employee', 'Gender', 9, None, 'NO', 'nchar', 1, 2, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('HireDate', 'AdventureWorks', 'HumanResources', 'Employee', 'HireDate', 10, None, 'NO', 'date', None, None, None, None, None, 0, None, None, None, None, None, None, None, None, None),
#  ('SalariedFlag', 'AdventureWorks', 'HumanResources', 'Employee', 'SalariedFlag', 11, '((1))', 'NO', 'bit', None, None, None, None, None, None, None, None, None, None, None, None, 'AdventureWorks', 'dbo', 'Flag'),
#  ('VacationHours', 'AdventureWorks', 'HumanResources', 'Employee', 'VacationHours', 12, '((0))', 'NO', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('SickLeaveHours', 'AdventureWorks', 'HumanResources', 'Employee', 'SickLeaveHours', 13, '((0))', 'NO', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('CurrentFlag', 'AdventureWorks', 'HumanResources', 'Employee', 'CurrentFlag', 14, '((1))', 'NO', 'bit', None, None, None, None, None, None, None, None, None, None, None, None, 'AdventureWorks', 'dbo', 'Flag'),
#  ('rowguid', 'AdventureWorks', 'HumanResources', 'Employee', 'rowguid', 15, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('ModifiedDate', 'AdventureWorks', 'HumanResources', 'Employee', 'ModifiedDate', 16, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('SalesOrderID', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'SalesOrderID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('RevisionNumber', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'RevisionNumber', 2, '((0))', 'NO', 'tinyint', None, None, 3, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('OrderDate', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'OrderDate', 3, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('DueDate', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'DueDate', 4, None, 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('ShipDate', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'ShipDate', 5, None, 'YES', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('Status', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'Status', 6, '((1))', 'NO', 'tinyint', None, None, 3, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('OnlineOrderFlag', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'OnlineOrderFlag', 7, '((1))', 'NO', 'bit', None, None, None, None, None, None, None, None, None, None, None, None, 'AdventureWorks', 'dbo', 'Flag'),
#  ('SalesOrderNumber', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'SalesOrderNumber', 8, None, 'NO', 'nvarchar', 25, 50, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('PurchaseOrderNumber', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'PurchaseOrderNumber', 9, None, 'YES', 'nvarchar', 25, 50, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'OrderNumber'),
#  ('AccountNumber', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'AccountNumber', 10, None, 'YES', 'nvarchar', 15, 30, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', 'AdventureWorks', 'dbo', 'AccountNumber'),
#  ('CustomerID', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'CustomerID', 11, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('SalesPersonID', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'SalesPersonID', 12, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('TerritoryID', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'TerritoryID', 13, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('BillToAddressID', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'BillToAddressID', 14, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('ShipToAddressID', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'ShipToAddressID', 15, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('ShipMethodID', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'ShipMethodID', 16, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('CreditCardID', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'CreditCardID', 17, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('CreditCardApprovalCode', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'CreditCardApprovalCode', 18, None, 'YES', 'varchar', 15, 15, None, None, None, None, None, None, 'iso_1', None, None, 'French_CI_AS', None, None, None),
#  ('CurrencyRateID', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'CurrencyRateID', 19, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('SubTotal', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'SubTotal', 20, '((0.00))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('TaxAmt', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'TaxAmt', 21, '((0.00))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('Freight', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'Freight', 22, '((0.00))', 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('TotalDue', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'TotalDue', 23, None, 'NO', 'money', None, None, 19, 10, 4, None, None, None, None, None, None, None, None, None, None),
#  ('Comment', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'Comment', 24, None, 'YES', 'nvarchar', 128, 256, None, None, None, None, None, None, 'UNICODE', None, None, 'French_CI_AS', None, None, None),
#  ('rowguid', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'rowguid', 25, '(newid())', 'NO', 'uniqueidentifier', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
#  ('ModifiedDate', 'AdventureWorks', 'Sales', 'SalesOrderHeader', 'ModifiedDate', 26, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('BusinessEntityID', 'AdventureWorks', 'HumanResources', 'EmployeeDepartmentHistory', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('DepartmentID', 'AdventureWorks', 'HumanResources', 'EmployeeDepartmentHistory', 'DepartmentID', 2, None, 'NO', 'smallint', None, None, 5, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('ShiftID', 'AdventureWorks', 'HumanResources', 'EmployeeDepartmentHistory', 'ShiftID', 3, None, 'NO', 'tinyint', None, None, 3, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('StartDate', 'AdventureWorks', 'HumanResources', 'EmployeeDepartmentHistory', 'StartDate', 4, None, 'NO', 'date', None, None, None, None, None, 0, None, None, None, None, None, None, None, None, None),
#  ('EndDate', 'AdventureWorks', 'HumanResources', 'EmployeeDepartmentHistory', 'EndDate', 5, None, 'YES', 'date', None, None, None, None, None, 0, None, None, None, None, None, None, None, None, None),
#  ('ModifiedDate', 'AdventureWorks', 'HumanResources', 'EmployeeDepartmentHistory', 'ModifiedDate', 6, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None)]

# %%
Headerlist=[]
for i in range(len(rows)):
    if rows[i][3]=='SalesOrderHeader':
        Headerlist.append(rows[i][0])
print (Headerlist)
# Out:
# ['SalesOrderID', 'RevisionNumber', 'OrderDate', 'DueDate', 'ShipDate', 'Status', 'OnlineOrderFlag', 'SalesOrderNumber', 'PurchaseOrderNumber', 'AccountNumber', 'CustomerID', 'SalesPersonID', 'TerritoryID', 'BillToAddressID', 'ShipToAddressID', 'ShipMethodID', 'CreditCardID', 'CreditCardApprovalCode', 'CurrencyRateID', 'SubTotal', 'TaxAmt', 'Freight', 'TotalDue', 'Comment', 'rowguid', 'ModifiedDate']

# %%
df = pd.read_csv('C:\\Users\\yoyo\\Documents\\Adventure Works\\AdventureWorks\AdventureWorks-csv (copy samples)\\SalesOrderHeader.csv', '\t',
                names=Headerlist)
df.shape
df.head()
# print(type(df))
# Out:
#    SalesOrderID  RevisionNumber            OrderDate              DueDate  \
# 0         43659               8  2011-05-31 00:00:00  2011-06-12 00:00:00
# 1         43660               8  2011-05-31 00:00:00  2011-06-12 00:00:00
# 2         43661               8  2011-05-31 00:00:00  2011-06-12 00:00:00
# 3         43662               8  2011-05-31 00:00:00  2011-06-12 00:00:00
# 4         43663               8  2011-05-31 00:00:00  2011-06-12 00:00:00
#
#               ShipDate  Status  OnlineOrderFlag SalesOrderNumber  \
# 0  2011-06-07 00:00:00       5                0          SO43659
# 1  2011-06-07 00:00:00       5                0          SO43660
# 2  2011-06-07 00:00:00       5                0          SO43661
# 3  2011-06-07 00:00:00       5                0          SO43662
# 4  2011-06-07 00:00:00       5                0          SO43663
#
#   PurchaseOrderNumber   AccountNumber  ...  CreditCardID  \
# 0         PO522145787  10-4020-000676  ...       16281.0
# 1       PO18850127500  10-4020-000117  ...        5618.0
# 2       PO18473189620  10-4020-000442  ...        1346.0
# 3       PO18444174044  10-4020-000227  ...       10456.0
# 4       PO18009186470  10-4020-000510  ...        4322.0
#
#    CreditCardApprovalCode  CurrencyRateID    SubTotal     TaxAmt   Freight  \
# 0           105041Vi84182             NaN  20565.6206  1971.5149  616.0984
# 1           115213Vi29411             NaN   1294.2529   124.2483   38.8276
# 2             85274Vi6854             4.0  32726.4786  3153.7696  985.5530
# 3           125295Vi53935             4.0  28832.5289  2775.1646  867.2389
# 4            45303Vi22691             NaN    419.4589    40.2681   12.5838
#
#      TotalDue Comment                                 rowguid  \
# 0  23153.2339     NaN  {79B65321-39CA-4115-9CBA-8FE0903E12E6}
# 1   1457.3288     NaN  {738DC42D-D03B-48A1-9822-F95A67EA7389}
# 2  36865.8012     NaN  {D91B9131-18A4-4A11-BC3A-90B6F53E9D74}
# 3  32474.9324     NaN  {4A1ECFC0-CC3A-4740-B028-1C50BB48711C}
# 4    472.3108     NaN  {9B1E7A40-6AE0-4AD3-811C-A64951857C4B}
#
#           ModifiedDate
# 0  2011-06-07 00:00:00
# 1  2011-06-07 00:00:00
# 2  2011-06-07 00:00:00
# 3  2011-06-07 00:00:00
# 4  2011-06-07 00:00:00
#
# [5 rows x 26 columns]

# %%
df_Table_SalesOrderHeader=df[["SalesOrderID","OrderDate","DueDate","ShipDate","OnlineOrderFlag","CustomerID","SalesPersonID","BillToAddressID","ShipToAddressID","TotalDue","ModifiedDate"]]
df_Table_SalesOrderHeader.to_csv('C:\\ProgramData\\MySQL\\MySQL Server 8.0\\Uploads\\AW\\SalesOrderHeader1.csv',index=False)

# %%
cursor = conn.cursor()

# %%
cursor.execute('select top 10 * from sales.Customer join person.person on person.person.BusinessEntityID=sales.Customer.PersonID;')
rows = cursor.fetchall()
len(rows[1])
# Out:
# 20
