# %%
import pandas as pd
import pyodbc
import pymysql
import matplotlib.pyplot as plt
import plotly as py
import plotly.graph_objs as go
import pandas as pd

# %%
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
py.__version__
# Out:
# '3.10.0'

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
iplot([{"x": [1, 2, 3], "y": [3, 1, 6]}])
# Out:
# <div>
#
#
#             <div id="c06148ec-2f91-4463-9c39-02403ecbf15c" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c06148ec-2f91-4463-9c39-02403ecbf15c")) {
#                     Plotly.newPlot(
#                         'c06148ec-2f91-4463-9c39-02403ecbf15c',
#                         [{"type": "scatter", "uid": "fb62c5da-169e-4450-b2ab-13d4fd28044e", "x": [1, 2, 3], "y": [3, 1, 6]}],
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('c06148ec-2f91-4463-9c39-02403ecbf15c');
# ...

# %%
def data_slice(rows,x):
    data=[]
    for i in range(len(rows)):
        data.append(rows[i][x])
        
    return data

# %%
conn=pymysql.connect(database='adventureworks',user='root',password='')
cursor=conn.cursor()
cursor.execute('select count(Address.AddressID), StateProvince.CountryRegionCode from Address left join StateProvince on Address.StateProvinceID=StateProvince.StateProvinceID group by StateProvince.CountryRegionCode;')
# Out:
# 6

# %%
rows = cursor.fetchall()

# %%
data=rows
data
# Out:
# ((1688, 'CA'),
#  (8668, 'US'),
#  (1821, 'DE'),
#  (1954, 'GB'),
#  (3632, 'AU'),
#  (1851, 'FR'))

# %%
data.iloc[:,[1]]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-162-4caf956a0c59> in <module>
# ----> 1 data.iloc[:,[1]]
#
# AttributeError: 'tuple' object has no attribute 'iloc'

# %%
Order_Number=data_slice(data,0)
Order_Number
# Out:
# [1688, 8668, 1821, 1954, 3632, 1851]

# %%
print(Order_Number)
# Out:
# [1688, 8668, 1821, 1954, 3632, 1851]

# %%
Country=data_slice(data,1)
Country
# Out:
# ['CA', 'US', 'DE', 'GB', 'AU', 'FR']

# %%
df=pd.DataFrame({'Order_Number':Order_Number , 'Country': Country},index = ['a1', 'a2', 'a3','a4','a5','a6'])

# %%
df
# Out:
#     Order_Number Country
# a1          1688      CA
# a2          8668      US
# a3          1821      DE
# a4          1954      GB
# a5          3632      AU
# a6          1851      FR

# %%
type(Order_Number)
# Out:
# list

# %%
type(Country)
# Out:
# list

# %%
iplot({
    [go.Scatter(x=[1, 2, 3, 4], y=[4, 3, 2, 1])],
    "layout": go.Layout(title="hello world")
}, auto_open=True)
# Out:
# 'temp-plot.html'

# %%
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
data=[go.Bar(
    x= Country, 
    y= Order_Number)]
layout=go.Layout(title="Order Number by Country")
fig=go.Figure(data, layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="138bd8f9-dc61-4e0c-9687-3d5b4006b30e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("138bd8f9-dc61-4e0c-9687-3d5b4006b30e")) {
#                     Plotly.newPlot(
#                         '138bd8f9-dc61-4e0c-9687-3d5b4006b30e',
#                         [{"type": "bar", "uid": "c4bc646e-a8f4-41e8-8016-168904a0f772", "x": ["CA", "US", "DE", "GB", "AU", "FR"], "y": [1688, 8668, 1821, 1954, 3632, 1851]}],
#                         {"title": {"text": "Order Number by Country"}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# ...

# %%
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

data = [go.Bar(
            x=['giraffes', 'orangutans', 'monkeys'],
            y=[20, 14, 23]
    )]

iplot(data)
# Out:
# <div>
#
#
#             <div id="46aab923-b1f2-4b81-b687-9eb1669f94e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("46aab923-b1f2-4b81-b687-9eb1669f94e8")) {
#                     Plotly.newPlot(
#                         '46aab923-b1f2-4b81-b687-9eb1669f94e8',
#                         [{"type": "bar", "uid": "2ecec353-e8bf-413e-b66a-95bbee8bc6dc", "x": ["giraffes", "orangutans", "monkeys"], "y": [20, 14, 23]}],
#                         {},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# ...

# %%
conn = pyodbc.connect('Driver={SQL Server};'
                      'Server=DESKTOP-JT7GQBL\SQLEXPRESS;'
                      'Database=AdventureWorks;'
                      'Trusted_Connection=yes;')

# %%
cursor = conn.cursor()

# %%
cursor.execute('SELECT COLUMN_NAME, * FROM INFORMATION_SCHEMA.COLUMNS')
rows = cursor.fetchall()
rows
# Out:
# [('SalesOrderID', 'AdventureWorks', 'Sales', 'SalesOrderHeaderSalesReason', 'SalesOrderID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('SalesReasonID', 'AdventureWorks', 'Sales', 'SalesOrderHeaderSalesReason', 'SalesReasonID', 2, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('ModifiedDate', 'AdventureWorks', 'Sales', 'SalesOrderHeaderSalesReason', 'ModifiedDate', 3, '(getdate())', 'NO', 'datetime', None, None, None, None, None, 3, None, None, None, None, None, None, None, None, None),
#  ('BusinessEntityID', 'AdventureWorks', 'Sales', 'SalesPerson', 'BusinessEntityID', 1, None, 'NO', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
#  ('TerritoryID', 'AdventureWorks', 'Sales', 'SalesPerson', 'TerritoryID', 2, None, 'YES', 'int', None, None, 10, 10, 0, None, None, None, None, None, None, None, None, None, None),
# ...

# %%
Headerlist=[]
for i in range(len(rows)):
    if rows[i][3]=='SalesOrderHeader':
        Headerlist.append(rows[i][0])
print (Headerlist)

# %%
df = pd.read_csv('C:\\Users\\yoyo\\Documents\\Adventure Works\\AdventureWorks\AdventureWorks-csv (copy samples)\\SalesOrderHeader.csv', '\t',
                names=Headerlist)
df.shape
df.head()
# print(type(df))

# %%
df_Table_SalesOrderHeader=df[["SalesOrderID","OrderDate","DueDate","ShipDate","OnlineOrderFlag","CustomerID","SalesPersonID","BillToAddressID","ShipToAddressID","TotalDue","ModifiedDate"]]
df_Table_SalesOrderHeader.to_csv('C:\\ProgramData\\MySQL\\MySQL Server 8.0\\Uploads\\AW\\SalesOrderHeader1.csv',index=False)

# %%
cursor = conn.cursor()

# %%
cursor.execute('select * from sales.Customer join person.person on person.person.BusinessEntityID=sales.Customer.PersonID;')
rows = cursor.fetchall()
rows
# Out:
# [(29484, 291, 292, 5, 'AW00029484', 'A24C1240-1A8D-427B-91E9-6197F8CF3CAD', datetime.datetime(2014, 9, 12, 11, 15, 7, 263000), 291, 'SC', False, 'Mr.', 'Gustavo', None, 'Achong', None, 2, '<AdditionalContactInfo xmlns="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/ContactInfo" xmlns:crm="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/ContactRecord" xmlns:act="http://schemas.microsoft.com/sqlserver/2004/07/adventure-works/ContactTypes"><act:telephoneNumber><act:number>425-555-1112</act:number><act:SpecialInstructions>Call only after 5:00 p.m.</act:SpecialInstructions></act:telephoneNumber>Note that the customer has a secondary home address.<act:homePostalAddress><act:Street>123 Oak</act:Street><act:City>Seattle</act:City><act:StateProvince>WA</act:StateProvince><act:PostalCode>98001</act:PostalCode><act:CountryRegion>USA</act:CountryRegion><act:SpecialInstructions>If correspondence to the primary address fails, try this one.</act:SpecialInstructions></
# ...

# %%
rows[29][1]

# %%
data=[]
for i in range(len(rows)):
    data.append(rows[i][0])
print (data)

# %%
def data_slice(rows,data,x):
    data=[]
    for i in range(len(rows)):
        data.append(rows[i][x])
    print (data)

# %%
import data_slice

# %%
data_slice(rows,[],1)
# Out:
# [291, 293, 295, 297, 299, 301, 303, 305, 307, 309, 311, 313, 315, 317, 319, 323, 325, 327, 329, 331, 333, 335, 337, 339, 341, 343, 345, 347, 349, 351, 353, 355, 357, 359, 361, 363, 365, 367, 369, 371, 373, 375, 377, 379, 381, 383, 385, 387, 389, 391, 393, 397, 405, 407, 409, 411, 413, 417, 419, 421, 427, 429, 431, 435, 437, 439, 441, 443, 445, 449, 451, 453, 455, 463, 465, 471, 473, 475, 477, 479, 481, 483, 487, 489, 491, 493, 495, 497, 501, 503, 505, 507, 509, 511, 513, 515, 517, 519, 521, 523, 525, 527, 531, 533, 535, 537, 539, 541, 543, 545, 547, 549, 551, 553, 555, 557, 559, 561, 563, 565, 567, 569, 573, 577, 579, 581, 583, 585, 587, 589, 591, 595, 597, 599, 601, 603, 607, 609, 611, 613, 615, 617, 619, 621, 623, 625, 627, 629, 631, 633, 635, 637, 639, 641, 643, 647, 649, 651, 653, 655, 657, 659, 661, 663, 665, 667, 669, 671, 675, 681, 683, 685, 687, 689, 691, 693, 695, 697, 699, 701, 703, 705, 707, 709, 713, 715, 717, 719, 721, 723, 725, 727, 729, 731, 733, 735, 737, 739, 741, 74
# ...
